# %%
# !pip install -q tensorflow tensorflow_datasets tensorflow_text

# %%
import logging
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow_text as text
import time

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)
train_examples, val_examples = examples['train'], examples['validation']

# carregar tokenizer

model_name = "ted_hrlr_translate_pt_en_converter"
tf.keras.utils.get_file(
    f"{model_name}.zip",
    f"https://storage.googleapis.com/download.tensorflow.org/models/{model_name}.zip",
    cache_dir='.', cache_subdir='', extract=True
)

tokenizers = tf.saved_model.load(model_name)

# pipeline de entrada e saída

BUFFER_SIZE = 20000
BATCH_SIZE = 64

def tokenize_pairs(pt, en):
    pt = tokenizers.pt.tokenize(pt)
    pt = pt.to_tensor()

    en = tokenizers.en.tokenize(en)
    en = en.to_tensor()
    return pt, en

def make_batches(ds):
    return(
        ds
      .cache()
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(tokenize_pairs, num_parallel_calls=tf.data.AUTOTUNE)
      .prefetch(tf.data.AUTOTUNE)
    )

train_batches = make_batches(train_examples)
val_batches = make_batches(val_examples)
# Out:
# Downloading and preparing dataset 124.94 MiB (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/51785 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.Q7OVLM_1.0.0/ted_hrlr_translate-tra…
# Generating validation examples...:   0%|          | 0/1193 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.Q7OVLM_1.0.0/ted_hrlr_translate-val…
# Generating test examples...:   0%|          | 0/1803 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.Q7OVLM_1.0.0/ted_hrlr_translate-tes…
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0. Subsequent calls will reuse this data.
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/models/ted_hrlr_translate_pt_en_converter.zip
# 184801/184801 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# positional_encoding

def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

# função para codificar o token baseado na posição
def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)    

# feed foward

def point_wise_feed_foward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)])
  
# attention

def scaled_dot_product_attention(q, k, v, mask):

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights

  
# encoder - decoder

class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate = 0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_foward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):
    attn_output, _ = self.mha(x, x, x, mask)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)

    ffn_output = self.ffn(out1)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)

    return out2

class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding,
                                            self.d_model)

    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]

    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]

    x = self.embedding(x) 
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training = training, mask = mask)

    return x 

class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()
        
        self.mha1 = MultiHeadAttention(d_model, num_heads) 
        self.mha2 = MultiHeadAttention(d_model, num_heads) 

        self.ffn = point_wise_feed_foward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2
    
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}

    x = self.embedding(x)  
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training = training,
                                             look_ahead_mask = look_ahead_mask, padding_mask = padding_mask)

      attention_weights[f'decoder_layer{i+1}_block1'] = block1
      attention_weights[f'decoder_layer{i+1}_block2'] = block2

    return x, attention_weights

class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super().__init__()
    self.encoder = Encoder(num_layers, d_model, num_heads, dff,
                             input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff,
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)

  def call(self, inputs, training):
    # Keras models prefer if you pass all your inputs in the first argument
    inp, tar = inputs

    enc_padding_mask, look_ahead_mask, dec_padding_mask = self.create_masks(inp, tar)

    enc_output = self.encoder(inp, training = training, mask = enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

    dec_output, attention_weights = self.decoder(
        tar, enc_output, training = training, look_ahead_mask = look_ahead_mask, padding_mask = dec_padding_mask)

    final_output = self.final_layer(dec_output)  

    return final_output, attention_weights

  def create_masks(self, inp, tar):
    seq = tf.cast(tf.math.equal(inp, 0), tf.float32)
    enc_padding_mask = seq[:, tf.newaxis, tf.newaxis, :]

    seq = tf.cast(tf.math.equal(inp, 0), tf.float32)
    dec_padding_mask = seq[:, tf.newaxis, tf.newaxis, :]

    size = tf.shape(tar)[1]
    look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)

    seq = tf.cast(tf.math.equal(tar, 0), tf.float32)
    dec_target_padding_mask = seq[:, tf.newaxis, tf.newaxis, :]
    look_ahead_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, look_ahead_mask, dec_padding_mask

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)



def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))

  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)

  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
# hiperparâmetros 

num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1

# otimizador

learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# métricas

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# instanciar modelo

translation_transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=tokenizers.pt.get_vocab_size().numpy(),
    target_vocab_size=tokenizers.en.get_vocab_size().numpy(),
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=translation_transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print('Latest checkpoint restored!!')
  
EPOCHS = 20

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]


@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  with tf.GradientTape() as tape:
    predictions, _ = translation_transformer([inp, tar_inp], training = True)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, translation_transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, translation_transformer.trainable_variables))

  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))
  

for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_state()
  train_accuracy.reset_state()

  # inp -> portuguese, tar -> english
  for (batch, (inp, tar)) in enumerate(train_batches):
    train_step(inp, tar)

    if batch % 50 == 0:
      print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

  print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 8.8855 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 8.8272 Accuracy 0.0023
# Epoch 1 Batch 100 Loss 8.7154 Accuracy 0.0260
# Epoch 1 Batch 150 Loss 8.5948 Accuracy 0.0388
# Epoch 1 Batch 200 Loss 8.4512 Accuracy 0.0479
# Epoch 1 Batch 250 Loss 8.2808 Accuracy 0.0582
# Epoch 1 Batch 300 Loss 8.0885 Accuracy 0.0672
# Epoch 1 Batch 350 Loss 7.8899 Accuracy 0.0741
# Epoch 1 Batch 400 Loss 7.7025 Accuracy 0.0798
# Epoch 1 Batch 450 Loss 7.5322 Accuracy 0.0853
# Epoch 1 Batch 500 Loss 7.3833 Accuracy 0.0911
# Epoch 1 Batch 550 Loss 7.2488 Accuracy 0.0977
# Epoch 1 Batch 600 Loss 7.1214 Accuracy 0.1047
# Epoch 1 Batch 650 Loss 7.0036 Accuracy 0.1111
# Epoch 1 Batch 700 Loss 6.8927 Accuracy 0.1173
# Epoch 1 Batch 750 Loss 6.7902 Accuracy 0.1231
# Epoch 1 Batch 800 Loss 6.6958 Accuracy 0.1285
# Epoch 1 Loss 6.6799 Accuracy 0.1295
# Time taken for 1 epoch: 130.17 secs
#
# Epoch 2 Batch 0 Loss 5.2646 Accuracy 0.2064
# Epoch 2 Batch 50 Loss 5.2215 Accuracy 0.2142
# Epoch 2 Batch 100 Loss 5.1862 Accuracy 0.2182
# Epoch 2 Batch 150 Loss 5.1435 Accuracy 0.2228
# Epoch 2 Batch 200 Loss 5.1195 Accuracy 0.2254
# Epoch 2 Batch 250 Loss 5.0927 Accuracy 0.2283
# Epoch 2 Batch 300 Loss 5.0637 Accuracy 0.2315
# Epoch 2 Batch 350 Loss 5.0439 Accuracy 0.2334
# Epoch 2 Batch 400 Loss 5.0226 Accuracy 0.2356
# Epoch 2 Batch 450 Loss 4.9997 Accuracy 0.2375
# Epoch 2 Batch 500 Loss 4.9794 Accuracy 0.2396
# Epoch 2 Batch 550 Loss 4.9640 Accuracy 0.2409
# Epoch 2 Batch 600 Loss 4.9423 Accuracy 0.2427
# Epoch 2 Batch 650 Loss 4.9234 Accuracy 0.2443
# Epoch 2 Batch 700 Loss 4.9073 Accuracy 0.2457
# Epoch 2 Batch 750 Loss 4.8906 Accuracy 0.2470
# Epoch 2 Batch 800 Loss 4.8760 Accuracy 0.2482
# Epoch 2 Loss 4.8733 Accuracy 0.2484
# Time taken for 1 epoch: 104.31 secs
#
# Epoch 3 Batch 0 Loss 4.6024 Accuracy 0.2692
# Epoch 3 Batch 50 Loss 4.5692 Accuracy 0.2734
# Epoch 3 Batch 100 Loss 4.5678 Accuracy 0.2722
# Epoch 3 Batch 150 Loss 4.5641 Accuracy 0.2734
# Epoch 3 Batch 200 Loss 4.5553 Accuracy 0.2742
# Epoch 3 Batch 250 Loss 4.5369 Accuracy 0.2764
# Epoch 3 Batch 300 Loss 4.5161 Accuracy 0.2784
# Epoch 3 Batch 350 Loss 4.5066 Accuracy 0.2794
# Epoch 3 Batch 400 Loss 4.4922 Accuracy 0.2814
# Epoch 3 Batch 450 Loss 4.4793 Accuracy 0.2832
# Epoch 3 Batch 500 Loss 4.4611 Accuracy 0.2852
# Epoch 3 Batch 550 Loss 4.4452 Accuracy 0.2872
# Epoch 3 Batch 600 Loss 4.4278 Accuracy 0.2895
# Epoch 3 Batch 650 Loss 4.4107 Accuracy 0.2917
# Epoch 3 Batch 700 Loss 4.3934 Accuracy 0.2939
# Epoch 3 Batch 750 Loss 4.3793 Accuracy 0.2957
# Epoch 3 Batch 800 Loss 4.3631 Accuracy 0.2979
# Epoch 3 Loss 4.3597 Accuracy 0.2984
# Time taken for 1 epoch: 106.80 secs
#
# Epoch 4 Batch 0 Loss 4.2118 Accuracy 0.3090
# Epoch 4 Batch 50 Loss 4.0104 Accuracy 0.3392
# Epoch 4 Batch 100 Loss 3.9796 Accuracy 0.3429
# Epoch 4 Batch 150 Loss 3.9700 Accuracy 0.3436
# Epoch 4 Batch 200 Loss 3.9572 Accuracy 0.3452
# Epoch 4 Batch 250 Loss 3.9432 Accuracy 0.3472
# Epoch 4 Batch 300 Loss 3.9269 Accuracy 0.3497
# Epoch 4 Batch 350 Loss 3.9135 Accuracy 0.3517
# Epoch 4 Batch 400 Loss 3.8996 Accuracy 0.3536
# Epoch 4 Batch 450 Loss 3.8864 Accuracy 0.3555
# Epoch 4 Batch 500 Loss 3.8704 Accuracy 0.3576
# Epoch 4 Batch 550 Loss 3.8557 Accuracy 0.3596
# Epoch 4 Batch 600 Loss 3.8449 Accuracy 0.3609
# Epoch 4 Batch 650 Loss 3.8297 Accuracy 0.3628
# Epoch 4 Batch 700 Loss 3.8152 Accuracy 0.3647
# Epoch 4 Batch 750 Loss 3.8028 Accuracy 0.3664
# Epoch 4 Batch 800 Loss 3.7900 Accuracy 0.3680
# Epoch 4 Loss 3.7882 Accuracy 0.3682
# Time taken for 1 epoch: 106.44 secs
#
# Epoch 5 Batch 0 Loss 3.5773 Accuracy 0.3776
# Epoch 5 Batch 50 Loss 3.5079 Accuracy 0.3998
# Epoch 5 Batch 100 Loss 3.4812 Accuracy 0.4040
# Epoch 5 Batch 150 Loss 3.4598 Accuracy 0.4069
# Epoch 5 Batch 200 Loss 3.4570 Accuracy 0.4072
# Epoch 5 Batch 250 Loss 3.4451 Accuracy 0.4090
# Epoch 5 Batch 300 Loss 3.4355 Accuracy 0.4102
# Epoch 5 Batch 350 Loss 3.4283 Accuracy 0.4110
# Epoch 5 Batch 400 Loss 3.4221 Accuracy 0.4120
# Epoch 5 Batch 450 Loss 3.4115 Accuracy 0.4132
# Epoch 5 Batch 500 Loss 3.4032 Accuracy 0.4144
# Epoch 5 Batch 550 Loss 3.3951 Accuracy 0.4154
# Epoch 5 Batch 600 Loss 3.3849 Accuracy 0.4168
# Epoch 5 Batch 650 Loss 3.3739 Accuracy 0.4180
# Epoch 5 Batch 700 Loss 3.3654 Accuracy 0.4192
# Epoch 5 Batch 750 Loss 3.3556 Accuracy 0.4205
# Epoch 5 Batch 800 Loss 3.3480 Accuracy 0.4216
# Saving checkpoint for epoch 5 at ./checkpoints/train/ckpt-1
# Epoch 5 Loss 3.3471 Accuracy 0.4218
# Time taken for 1 epoch: 106.95 secs
#
# Epoch 6 Batch 0 Loss 3.1414 Accuracy 0.4399
# Epoch 6 Batch 50 Loss 3.0634 Accuracy 0.4544
# Epoch 6 Batch 100 Loss 3.0498 Accuracy 0.4567
# Epoch 6 Batch 150 Loss 3.0550 Accuracy 0.4556
# Epoch 6 Batch 200 Loss 3.0488 Accuracy 0.4564
# Epoch 6 Batch 250 Loss 3.0442 Accuracy 0.4578
# Epoch 6 Batch 300 Loss 3.0345 Accuracy 0.4589
# Epoch 6 Batch 350 Loss 3.0231 Accuracy 0.4603
# Epoch 6 Batch 400 Loss 3.0138 Accuracy 0.4615
# Epoch 6 Batch 450 Loss 3.0034 Accuracy 0.4632
# Epoch 6 Batch 500 Loss 2.9955 Accuracy 0.4641
# Epoch 6 Batch 550 Loss 2.9839 Accuracy 0.4657
# Epoch 6 Batch 600 Loss 2.9751 Accuracy 0.4671
# Epoch 6 Batch 650 Loss 2.9688 Accuracy 0.4681
# Epoch 6 Batch 700 Loss 2.9627 Accuracy 0.4689
# Epoch 6 Batch 750 Loss 2.9570 Accuracy 0.4699
# Epoch 6 Batch 800 Loss 2.9496 Accuracy 0.4710
# Epoch 6 Loss 2.9477 Accuracy 0.4714
# Time taken for 1 epoch: 105.92 secs
#
# Epoch 7 Batch 0 Loss 2.7226 Accuracy 0.4960
# Epoch 7 Batch 50 Loss 2.6743 Accuracy 0.5033
# Epoch 7 Batch 100 Loss 2.6627 Accuracy 0.5058
# Epoch 7 Batch 150 Loss 2.6608 Accuracy 0.5066
# Epoch 7 Batch 200 Loss 2.6538 Accuracy 0.5078
# Epoch 7 Batch 250 Loss 2.6556 Accuracy 0.5074
# Epoch 7 Batch 300 Loss 2.6496 Accuracy 0.5083
# Epoch 7 Batch 350 Loss 2.6479 Accuracy 0.5088
# Epoch 7 Batch 400 Loss 2.6488 Accuracy 0.5087
# Epoch 7 Batch 450 Loss 2.6429 Accuracy 0.5097
# Epoch 7 Batch 500 Loss 2.6380 Accuracy 0.5100
# Epoch 7 Batch 550 Loss 2.6316 Accuracy 0.5110
# Epoch 7 Batch 600 Loss 2.6316 Accuracy 0.5110
# Epoch 7 Batch 650 Loss 2.6269 Accuracy 0.5117
# Epoch 7 Batch 700 Loss 2.6234 Accuracy 0.5124
# Epoch 7 Batch 750 Loss 2.6208 Accuracy 0.5130
# Epoch 7 Batch 800 Loss 2.6153 Accuracy 0.5138
# Epoch 7 Loss 2.6150 Accuracy 0.5138
# Time taken for 1 epoch: 106.14 secs
#
# Epoch 8 Batch 0 Loss 2.4040 Accuracy 0.5304
# Epoch 8 Batch 50 Loss 2.4310 Accuracy 0.5353
# Epoch 8 Batch 100 Loss 2.4085 Accuracy 0.5398
# Epoch 8 Batch 150 Loss 2.4033 Accuracy 0.5401
# Epoch 8 Batch 200 Loss 2.4026 Accuracy 0.5408
# Epoch 8 Batch 250 Loss 2.4060 Accuracy 0.5403
# Epoch 8 Batch 300 Loss 2.4001 Accuracy 0.5415
# Epoch 8 Batch 350 Loss 2.3931 Accuracy 0.5425
# Epoch 8 Batch 400 Loss 2.3920 Accuracy 0.5427
# Epoch 8 Batch 450 Loss 2.3872 Accuracy 0.5433
# Epoch 8 Batch 500 Loss 2.3874 Accuracy 0.5433
# Epoch 8 Batch 550 Loss 2.3853 Accuracy 0.5437
# Epoch 8 Batch 600 Loss 2.3847 Accuracy 0.5440
# Epoch 8 Batch 650 Loss 2.3829 Accuracy 0.5445
# Epoch 8 Batch 700 Loss 2.3820 Accuracy 0.5446
# Epoch 8 Batch 750 Loss 2.3792 Accuracy 0.5451
# Epoch 8 Batch 800 Loss 2.3777 Accuracy 0.5455
# Epoch 8 Loss 2.3787 Accuracy 0.5452
# Time taken for 1 epoch: 106.27 secs
#
# Epoch 9 Batch 0 Loss 2.2227 Accuracy 0.5696
# Epoch 9 Batch 50 Loss 2.2011 Accuracy 0.5670
# Epoch 9 Batch 100 Loss 2.1858 Accuracy 0.5701
# Epoch 9 Batch 150 Loss 2.2032 Accuracy 0.5677
# Epoch 9 Batch 200 Loss 2.2125 Accuracy 0.5671
# Epoch 9 Batch 250 Loss 2.2106 Accuracy 0.5680
# Epoch 9 Batch 300 Loss 2.2108 Accuracy 0.5677
# Epoch 9 Batch 350 Loss 2.2072 Accuracy 0.5687
# Epoch 9 Batch 400 Loss 2.2063 Accuracy 0.5686
# Epoch 9 Batch 450 Loss 2.2078 Accuracy 0.5681
# Epoch 9 Batch 500 Loss 2.2027 Accuracy 0.5690
# Epoch 9 Batch 550 Loss 2.2045 Accuracy 0.5688
# Epoch 9 Batch 600 Loss 2.2047 Accuracy 0.5690
# Epoch 9 Batch 650 Loss 2.2058 Accuracy 0.5690
# Epoch 9 Batch 700 Loss 2.2054 Accuracy 0.5691
# Epoch 9 Batch 750 Loss 2.2072 Accuracy 0.5690
# Epoch 9 Batch 800 Loss 2.2063 Accuracy 0.5691
# Epoch 9 Loss 2.2068 Accuracy 0.5691
# Time taken for 1 epoch: 107.19 secs
#
# Epoch 10 Batch 0 Loss 1.8513 Accuracy 0.6220
# Epoch 10 Batch 50 Loss 2.0070 Accuracy 0.5975
# Epoch 10 Batch 100 Loss 2.0387 Accuracy 0.5918
# Epoch 10 Batch 150 Loss 2.0529 Accuracy 0.5896
# Epoch 10 Batch 200 Loss 2.0619 Accuracy 0.5884
# Epoch 10 Batch 250 Loss 2.0681 Accuracy 0.5871
# Epoch 10 Batch 300 Loss 2.0689 Accuracy 0.5874
# Epoch 10 Batch 350 Loss 2.0675 Accuracy 0.5876
# Epoch 10 Batch 400 Loss 2.0649 Accuracy 0.5879
# Epoch 10 Batch 450 Loss 2.0629 Accuracy 0.5883
# Epoch 10 Batch 500 Loss 2.0647 Accuracy 0.5881
# Epoch 10 Batch 550 Loss 2.0634 Accuracy 0.5885
# Epoch 10 Batch 600 Loss 2.0630 Accuracy 0.5888
# Epoch 10 Batch 650 Loss 2.0638 Accuracy 0.5888
# Epoch 10 Batch 700 Loss 2.0638 Accuracy 0.5890
# Epoch 10 Batch 750 Loss 2.0665 Accuracy 0.5886
# Epoch 10 Batch 800 Loss 2.0681 Accuracy 0.5884
# Saving checkpoint for epoch 10 at ./checkpoints/train/ckpt-2
# Epoch 10 Loss 2.0689 Accuracy 0.5883
# Time taken for 1 epoch: 106.52 secs
#
# Epoch 11 Batch 0 Loss 1.9207 Accuracy 0.6097
# Epoch 11 Batch 50 Loss 1.8914 Accuracy 0.6133
# Epoch 11 Batch 100 Loss 1.9191 Accuracy 0.6082
# Epoch 11 Batch 150 Loss 1.9272 Accuracy 0.6068
# Epoch 11 Batch 200 Loss 1.9386 Accuracy 0.6050
# Epoch 11 Batch 250 Loss 1.9397 Accuracy 0.6048
# Epoch 11 Batch 300 Loss 1.9374 Accuracy 0.6048
# Epoch 11 Batch 350 Loss 1.9351 Accuracy 0.6053
# Epoch 11 Batch 400 Loss 1.9443 Accuracy 0.6041
# Epoch 11 Batch 450 Loss 1.9474 Accuracy 0.6038
# Epoch 11 Batch 500 Loss 1.9502 Accuracy 0.6037
# Epoch 11 Batch 550 Loss 1.9499 Accuracy 0.6038
# Epoch 11 Batch 600 Loss 1.9532 Accuracy 0.6035
# Epoch 11 Batch 650 Loss 1.9517 Accuracy 0.6038
# Epoch 11 Batch 700 Loss 1.9523 Accuracy 0.6039
# Epoch 11 Batch 750 Loss 1.9545 Accuracy 0.6037
# Epoch 11 Batch 800 Loss 1.9564 Accuracy 0.6035
# Epoch 11 Loss 1.9570 Accuracy 0.6035
# Time taken for 1 epoch: 106.27 secs
#
# Epoch 12 Batch 0 Loss 1.8281 Accuracy 0.6291
# Epoch 12 Batch 50 Loss 1.8283 Accuracy 0.6217
# Epoch 12 Batch 100 Loss 1.8334 Accuracy 0.6212
# Epoch 12 Batch 150 Loss 1.8279 Accuracy 0.6221
# Epoch 12 Batch 200 Loss 1.8311 Accuracy 0.6219
# Epoch 12 Batch 250 Loss 1.8354 Accuracy 0.6208
# Epoch 12 Batch 300 Loss 1.8406 Accuracy 0.6196
# Epoch 12 Batch 350 Loss 1.8437 Accuracy 0.6193
# Epoch 12 Batch 400 Loss 1.8478 Accuracy 0.6188
# Epoch 12 Batch 450 Loss 1.8511 Accuracy 0.6182
# Epoch 12 Batch 500 Loss 1.8535 Accuracy 0.6177
# Epoch 12 Batch 550 Loss 1.8551 Accuracy 0.6177
# Epoch 12 Batch 600 Loss 1.8559 Accuracy 0.6178
# Epoch 12 Batch 650 Loss 1.8569 Accuracy 0.6180
# Epoch 12 Batch 700 Loss 1.8578 Accuracy 0.6180
# Epoch 12 Batch 750 Loss 1.8622 Accuracy 0.6174
# Epoch 12 Batch 800 Loss 1.8645 Accuracy 0.6172
# Epoch 12 Loss 1.8646 Accuracy 0.6171
# Time taken for 1 epoch: 106.14 secs
#
# Epoch 13 Batch 0 Loss 1.6868 Accuracy 0.6455
# Epoch 13 Batch 50 Loss 1.7518 Accuracy 0.6320
# Epoch 13 Batch 100 Loss 1.7514 Accuracy 0.6332
# Epoch 13 Batch 150 Loss 1.7501 Accuracy 0.6335
# Epoch 13 Batch 200 Loss 1.7525 Accuracy 0.6330
# Epoch 13 Batch 250 Loss 1.7563 Accuracy 0.6325
# Epoch 13 Batch 300 Loss 1.7583 Accuracy 0.6320
# Epoch 13 Batch 350 Loss 1.7661 Accuracy 0.6308
# Epoch 13 Batch 400 Loss 1.7687 Accuracy 0.6305
# Epoch 13 Batch 450 Loss 1.7716 Accuracy 0.6298
# Epoch 13 Batch 500 Loss 1.7739 Accuracy 0.6297
# Epoch 13 Batch 550 Loss 1.7756 Accuracy 0.6295
# Epoch 13 Batch 600 Loss 1.7758 Accuracy 0.6295
# Epoch 13 Batch 650 Loss 1.7779 Accuracy 0.6293
# Epoch 13 Batch 700 Loss 1.7801 Accuracy 0.6292
# Epoch 13 Batch 750 Loss 1.7829 Accuracy 0.6289
# Epoch 13 Batch 800 Loss 1.7861 Accuracy 0.6285
# Epoch 13 Loss 1.7858 Accuracy 0.6286
# Time taken for 1 epoch: 106.31 secs
#
# Epoch 14 Batch 0 Loss 1.7853 Accuracy 0.6245
# Epoch 14 Batch 50 Loss 1.6733 Accuracy 0.6464
# Epoch 14 Batch 100 Loss 1.6799 Accuracy 0.6451
# Epoch 14 Batch 150 Loss 1.6878 Accuracy 0.6430
# Epoch 14 Batch 200 Loss 1.6860 Accuracy 0.6432
# Epoch 14 Batch 250 Loss 1.6901 Accuracy 0.6426
# Epoch 14 Batch 300 Loss 1.6931 Accuracy 0.6418
# Epoch 14 Batch 350 Loss 1.6961 Accuracy 0.6414
# Epoch 14 Batch 400 Loss 1.6965 Accuracy 0.6412
# Epoch 14 Batch 450 Loss 1.7012 Accuracy 0.6405
# Epoch 14 Batch 500 Loss 1.7034 Accuracy 0.6404
# Epoch 14 Batch 550 Loss 1.7056 Accuracy 0.6402
# Epoch 14 Batch 600 Loss 1.7076 Accuracy 0.6400
# Epoch 14 Batch 650 Loss 1.7101 Accuracy 0.6396
# Epoch 14 Batch 700 Loss 1.7122 Accuracy 0.6393
# Epoch 14 Batch 750 Loss 1.7148 Accuracy 0.6390
# Epoch 14 Batch 800 Loss 1.7182 Accuracy 0.6387
# Epoch 14 Loss 1.7177 Accuracy 0.6387
# Time taken for 1 epoch: 106.46 secs
#
# Epoch 15 Batch 0 Loss 1.5783 Accuracy 0.6505
# Epoch 15 Batch 50 Loss 1.6197 Accuracy 0.6503
# Epoch 15 Batch 100 Loss 1.6216 Accuracy 0.6510
# Epoch 15 Batch 150 Loss 1.6244 Accuracy 0.6513
# Epoch 15 Batch 200 Loss 1.6256 Accuracy 0.6508
# Epoch 15 Batch 250 Loss 1.6253 Accuracy 0.6517
# Epoch 15 Batch 300 Loss 1.6281 Accuracy 0.6516
# Epoch 15 Batch 350 Loss 1.6324 Accuracy 0.6509
# Epoch 15 Batch 400 Loss 1.6386 Accuracy 0.6499
# Epoch 15 Batch 450 Loss 1.6421 Accuracy 0.6497
# Epoch 15 Batch 500 Loss 1.6421 Accuracy 0.6497
# Epoch 15 Batch 550 Loss 1.6426 Accuracy 0.6498
# Epoch 15 Batch 600 Loss 1.6462 Accuracy 0.6493
# Epoch 15 Batch 650 Loss 1.6492 Accuracy 0.6489
# Epoch 15 Batch 700 Loss 1.6510 Accuracy 0.6487
# Epoch 15 Batch 750 Loss 1.6534 Accuracy 0.6483
# Epoch 15 Batch 800 Loss 1.6562 Accuracy 0.6478
# Saving checkpoint for epoch 15 at ./checkpoints/train/ckpt-3
# Epoch 15 Loss 1.6566 Accuracy 0.6477
# Time taken for 1 epoch: 106.31 secs
#
# Epoch 16 Batch 0 Loss 1.4719 Accuracy 0.6972
# Epoch 16 Batch 50 Loss 1.5332 Accuracy 0.6675
# Epoch 16 Batch 100 Loss 1.5508 Accuracy 0.6640
# Epoch 16 Batch 150 Loss 1.5542 Accuracy 0.6642
# Epoch 16 Batch 200 Loss 1.5659 Accuracy 0.6619
# Epoch 16 Batch 250 Loss 1.5690 Accuracy 0.6613
# Epoch 16 Batch 300 Loss 1.5727 Accuracy 0.6606
# Epoch 16 Batch 350 Loss 1.5781 Accuracy 0.6596
# Epoch 16 Batch 400 Loss 1.5784 Accuracy 0.6595
# Epoch 16 Batch 450 Loss 1.5837 Accuracy 0.6589
# Epoch 16 Batch 500 Loss 1.5821 Accuracy 0.6591
# Epoch 16 Batch 550 Loss 1.5854 Accuracy 0.6588
# Epoch 16 Batch 600 Loss 1.5888 Accuracy 0.6583
# Epoch 16 Batch 650 Loss 1.5933 Accuracy 0.6578
# Epoch 16 Batch 700 Loss 1.5973 Accuracy 0.6572
# Epoch 16 Batch 750 Loss 1.5999 Accuracy 0.6569
# Epoch 16 Batch 800 Loss 1.6027 Accuracy 0.6565
# Epoch 16 Loss 1.6034 Accuracy 0.6563
# Time taken for 1 epoch: 105.86 secs
#
# Epoch 17 Batch 0 Loss 1.5372 Accuracy 0.6588
# Epoch 17 Batch 50 Loss 1.5118 Accuracy 0.6681
# Epoch 17 Batch 100 Loss 1.5185 Accuracy 0.6681
# Epoch 17 Batch 150 Loss 1.5159 Accuracy 0.6682
# Epoch 17 Batch 200 Loss 1.5242 Accuracy 0.6667
# Epoch 17 Batch 250 Loss 1.5197 Accuracy 0.6678
# Epoch 17 Batch 300 Loss 1.5260 Accuracy 0.6666
# Epoch 17 Batch 350 Loss 1.5279 Accuracy 0.6666
# Epoch 17 Batch 400 Loss 1.5314 Accuracy 0.6662
# Epoch 17 Batch 450 Loss 1.5349 Accuracy 0.6656
# Epoch 17 Batch 500 Loss 1.5369 Accuracy 0.6653
# Epoch 17 Batch 550 Loss 1.5408 Accuracy 0.6647
# Epoch 17 Batch 600 Loss 1.5458 Accuracy 0.6639
# Epoch 17 Batch 650 Loss 1.5471 Accuracy 0.6638
# Epoch 17 Batch 700 Loss 1.5515 Accuracy 0.6631
# Epoch 17 Batch 750 Loss 1.5538 Accuracy 0.6628
# Epoch 17 Batch 800 Loss 1.5550 Accuracy 0.6629
# Epoch 17 Loss 1.5555 Accuracy 0.6628
# Time taken for 1 epoch: 105.47 secs
#
# Epoch 18 Batch 0 Loss 1.2955 Accuracy 0.7154
# Epoch 18 Batch 50 Loss 1.4558 Accuracy 0.6787
# Epoch 18 Batch 100 Loss 1.4651 Accuracy 0.6783
# Epoch 18 Batch 150 Loss 1.4694 Accuracy 0.6771
# Epoch 18 Batch 200 Loss 1.4719 Accuracy 0.6765
# Epoch 18 Batch 250 Loss 1.4782 Accuracy 0.6752
# Epoch 18 Batch 300 Loss 1.4820 Accuracy 0.6746
# Epoch 18 Batch 350 Loss 1.4829 Accuracy 0.6745
# Epoch 18 Batch 400 Loss 1.4900 Accuracy 0.6737
# Epoch 18 Batch 450 Loss 1.4903 Accuracy 0.6736
# Epoch 18 Batch 500 Loss 1.4934 Accuracy 0.6730
# Epoch 18 Batch 550 Loss 1.4965 Accuracy 0.6725
# Epoch 18 Batch 600 Loss 1.5000 Accuracy 0.6719
# Epoch 18 Batch 650 Loss 1.5034 Accuracy 0.6714
# Epoch 18 Batch 700 Loss 1.5060 Accuracy 0.6710
# Epoch 18 Batch 750 Loss 1.5085 Accuracy 0.6706
# Epoch 18 Batch 800 Loss 1.5123 Accuracy 0.6700
# Epoch 18 Loss 1.5136 Accuracy 0.6698
# Time taken for 1 epoch: 106.05 secs
#
# Epoch 19 Batch 0 Loss 1.2108 Accuracy 0.7309
# Epoch 19 Batch 50 Loss 1.4063 Accuracy 0.6878
# Epoch 19 Batch 100 Loss 1.4168 Accuracy 0.6855
# Epoch 19 Batch 150 Loss 1.4315 Accuracy 0.6831
# Epoch 19 Batch 200 Loss 1.4317 Accuracy 0.6830
# Epoch 19 Batch 250 Loss 1.4421 Accuracy 0.6811
# Epoch 19 Batch 300 Loss 1.4421 Accuracy 0.6811
# Epoch 19 Batch 350 Loss 1.4462 Accuracy 0.6806
# Epoch 19 Batch 400 Loss 1.4515 Accuracy 0.6796
# Epoch 19 Batch 450 Loss 1.4571 Accuracy 0.6784
# Epoch 19 Batch 500 Loss 1.4594 Accuracy 0.6781
# Epoch 19 Batch 550 Loss 1.4609 Accuracy 0.6778
# Epoch 19 Batch 600 Loss 1.4632 Accuracy 0.6776
# Epoch 19 Batch 650 Loss 1.4645 Accuracy 0.6774
# Epoch 19 Batch 700 Loss 1.4675 Accuracy 0.6770
# Epoch 19 Batch 750 Loss 1.4696 Accuracy 0.6768
# Epoch 19 Batch 800 Loss 1.4722 Accuracy 0.6764
# Epoch 19 Loss 1.4733 Accuracy 0.6762
# Time taken for 1 epoch: 105.82 secs
#
# Epoch 20 Batch 0 Loss 1.5704 Accuracy 0.6595
# Epoch 20 Batch 50 Loss 1.3897 Accuracy 0.6898
# Epoch 20 Batch 100 Loss 1.3900 Accuracy 0.6907
# Epoch 20 Batch 150 Loss 1.4002 Accuracy 0.6876
# Epoch 20 Batch 200 Loss 1.4012 Accuracy 0.6876
# Epoch 20 Batch 250 Loss 1.4021 Accuracy 0.6873
# Epoch 20 Batch 300 Loss 1.4042 Accuracy 0.6870
# Epoch 20 Batch 350 Loss 1.4085 Accuracy 0.6862
# Epoch 20 Batch 400 Loss 1.4110 Accuracy 0.6860
# Epoch 20 Batch 450 Loss 1.4152 Accuracy 0.6852
# Epoch 20 Batch 500 Loss 1.4177 Accuracy 0.6847
# Epoch 20 Batch 550 Loss 1.4201 Accuracy 0.6844
# Epoch 20 Batch 600 Loss 1.4244 Accuracy 0.6838
# Epoch 20 Batch 650 Loss 1.4260 Accuracy 0.6835
# Epoch 20 Batch 700 Loss 1.4281 Accuracy 0.6833
# Epoch 20 Batch 750 Loss 1.4329 Accuracy 0.6826
# Epoch 20 Batch 800 Loss 1.4368 Accuracy 0.6818
# Saving checkpoint for epoch 20 at ./checkpoints/train/ckpt-4
# Epoch 20 Loss 1.4375 Accuracy 0.6817
# Time taken for 1 epoch: 107.45 secs

# %%
class Translator(tf.Module):
  def __init__(self, tokenizers, transformer):
    self.tokenizers = tokenizers
    self.transformer = transformer

  def __call__(self, sentence, max_length=20):
    # input sentence is portuguese, hence adding the start and end token
    assert isinstance(sentence, tf.Tensor)
    if len(sentence.shape) == 0:
      sentence = sentence[tf.newaxis]

    sentence = self.tokenizers.pt.tokenize(sentence).to_tensor()

    encoder_input = sentence

    # as the target is english, the first token to the transformer should be the
    # english start token.
    start_end = self.tokenizers.en.tokenize([''])[0]
    start = start_end[0][tf.newaxis]
    end = start_end[1][tf.newaxis]

    # `tf.TensorArray` is required here (instead of a python list) so that the
    # dynamic-loop can be traced by `tf.function`.
    output_array = tf.TensorArray(dtype=tf.int64, size=0, dynamic_size=True)
    output_array = output_array.write(0, start)

    for i in tf.range(max_length):
      output = tf.transpose(output_array.stack())
      predictions, _ = self.transformer([encoder_input, output], training=False)

      # select the last token from the seq_len dimension
      predictions = predictions[:, -1:, :]  # (batch_size, 1, vocab_size)

      predicted_id = tf.argmax(predictions, axis=-1)

      # concatentate the predicted_id to the output which is given to the decoder
      # as its input.
      output_array = output_array.write(i+1, predicted_id[0])

      if predicted_id == end:
        break

    output = tf.transpose(output_array.stack())
    # output.shape (1, tokens)
    text = tokenizers.en.detokenize(output)[0]  # shape: ()

    tokens = tokenizers.en.lookup(output)[0]

    # `tf.function` prevents us from using the attention_weights that were
    # calculated on the last iteration of the loop. So recalculate them outside
    # the loop.
    _, attention_weights = self.transformer([encoder_input, output[:,:-1]], training=False)

    return text, tokens, attention_weights

# %%
translator = Translator(tokenizers, translation_transformer)

# %%
def print_translation(sentence, tokens, ground_truth):
  print(f'{"Input:":15s}: {sentence}')
  print(f'{"Prediction":15s}: {tokens.numpy().decode("utf-8")}')
  print(f'{"Ground truth":15s}: {ground_truth}')

# %%
sentence = "este é um problema que temos que resolver."
ground_truth = "this is a problem we have to solve ."

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : este é um problema que temos que resolver.
# Prediction     : this is a problem we need to solve .
# Ground truth   : this is a problem we have to solve .

# %%
sentence = "Olá, mundo!"
ground_truth = "Hello, World!"

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : Olá, mundo!
# Prediction     : hi , world !
# Ground truth   : Hello, World!

# %%
sentence = "Hoje está calor"
ground_truth = "Today is hot"

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : Hoje está calor
# Prediction     : today , it ' s hot .
# Ground truth   : Today is hot

# %%
sentence = "Li sobre cortinas na internet"
ground_truth = "Read about curtains on internet"

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : Li sobre cortinas na internet
# Prediction     : i read about color - like displays on the internet .
# Ground truth   : Read about curtains on internet

# %%
sentence = "Eu uso o computador"
ground_truth = "I use the computer"

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : Eu uso o computador
# Prediction     : i use the computer to use the internet .
# Ground truth   : I use the computer

# %%
class ExportTranslator(tf.Module):
  def __init__(self, translator):
    self.translator = translator

  @tf.function(input_signature=[tf.TensorSpec(shape=[], dtype=tf.string)])
  def __call__(self, sentence):
    (result, 
     tokens,
     attention_weights) = self.translator(sentence, max_length=100)

    return result

translator = ExportTranslator(translator)

# %%
tf.saved_model.save(translator, export_dir='translator')
